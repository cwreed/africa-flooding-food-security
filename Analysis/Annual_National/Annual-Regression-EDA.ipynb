# %%
import os
import numpy as np
import pandas as pd
import geopandas as gpd
import statsmodels.formula.api as smf
import semopy
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.set_theme(rc = {'figure.figsize':(18,12)})

# %%
data_dir = '../../Data/'
df = gpd.read_file(os.path.join(data_dir, 'flood_ipc_covariates.gpkg')).drop('index', 1)

# %%
df.iloc[:, 9:19] = df.iloc[:, 9:19].astype('double')
df = df.rename(columns = {'Displacement incidents (flood estimate, IDMC)': 'displaced_flood_idmc',
                          'Displacement incidents (disaster, IDMC)': 'displaced_disaster_idmc',
                          'Flood estimate exact (IDMC)': 'flood_confirmed_idmc',
                          'Flash floods (IDMC)': 'flash_idmc',
                          'Displacement incidents (flash floods, IDMC)': 'displaced_flash_idmc',
                          'Total affected (floods, EM-DAT)': 'affected_flood_emdat',
                          'Flash floods (EM-DAT)': 'flash_confirmed_emdat',
                         'Total affected (flash floods, EM-DAT)': 'displaced_flash_emdat'})

# %%
df.loc[(df['ISO'] == 'NGA') & (df['Year'] == 2012)]
# Out:
#      ID_0  ISO     Name  OBJECTID_1      POP2000        SQKM     POPSQKM  \
# 56  163.0  NGA  Nigeria       166.0  113861753.0  912038.625  124.843126
# 57  163.0  NGA  Nigeria       166.0  113861753.0  912038.625  124.843126
# 58  163.0  NGA  Nigeria       166.0  113861753.0  912038.625  124.843126
# 59  163.0  NGA  Nigeria       166.0  113861753.0  912038.625  124.843126
# 60  163.0  NGA  Nigeria       166.0  113861753.0  912038.625  124.843126
# 61  163.0  NGA  Nigeria       166.0  113861753.0  912038.625  124.843126
# 62  163.0  NGA  Nigeria       166.0  113861753.0  912038.625  124.843126
#
#    GID_0  Year         flood_extent  ... mean_staple_price_3  \
# 56  None  2012                 None  ...    1.33743611146595
# 57  None  2013                 None  ...   1.536175881703105
# 58  None  2014  0.03042020437554908  ...    1.33285437566475
# 59  None  2015  0.03452153110332288  ...  0.9702720063265249
# 60  None  2016  0.03209580946540315  ...    1.50403279664514
# 61  None  2017  0.02947474126091631  ...    1.64235946387485
# 62  None  2018  0.03827615631672682  ...   1.363711026194485
#
#    Displacement incidents (disaster, IDMC) Flood estimate exact (IDMC)  \
# 56                               3900000.0                           0
# 57                                117000.0                           0
# 58                                  3000.0                           0
# 59                                100000.0                           0
# 60                                 78000.0                           0
# 61                                122000.0                           1
# 62                                613000.0                           1
#
#    Displacement incidents (flood estimate, IDMC) Flash floods (IDMC)  \
# 56                                     3315000.0                 NaN
# 57                                       99450.0                 NaN
# 58                                        2550.0                 NaN
# 59                                       85000.0                 NaN
# 60                                       66300.0                 NaN
# 61                                      120000.0                 0.0
# 62                                      604900.0                 0.0
#
#    Displacement incidents (flash floods, IDMC)  \
# 56                                         NaN
# 57                                         NaN
# 58                                         NaN
# 59                                         NaN
# 60                                         NaN
# 61                                         0.0
# 62                                         0.0
#
#    Total affected (floods, EM-DAT) Flash floods (EM-DAT)  \
# 56                       7000867.0                   0.0
# 57                         81506.0                   0.0
# 58                         10000.0                   0.0
# 59                        100420.0                   0.0
# 60                         12000.0                   0.0
# 61                         10500.0                   0.0
# 62                       1938204.0                   0.0
#
#    Total affected (flash floods, EM-DAT)  \
# 56                                   0.0
# 57                                   0.0
# 58                                   0.0
# 59                                   0.0
# 60                                   0.0
# 61                                   0.0
# 62                                   0.0
#
#                                              geometry
# 56  MULTIPOLYGON (((6.44042 4.30875, 6.44042 4.307...
# 57  MULTIPOLYGON (((6.44042 4.30875, 6.44042 4.307...
# 58  MULTIPOLYGON (((6.44042 4.30875, 6.44042 4.307...
# 59  MULTIPOLYGON (((6.44042 4.30875, 6.44042 4.307...
# 60  MULTIPOLYGON (((6.44042 4.30875, 6.44042 4.307...
# 61  MULTIPOLYGON (((6.44042 4.30875, 6.44042 4.307...
# 62  MULTIPOLYGON (((6.44042 4.30875, 6.44042 4.307...
#
# [7 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['ID_0', 'ISO', 'Name', 'OBJECTID_1', 'POP2000', 'SQKM', 'POPSQKM',
#        'GID_0', 'Year', 'flood_extent', 'mean_flood_duration', 'mean_ipc_0',
#        'mean_ipc_1', 'mean_ipc_2', 'mean_ipc_3', 'mean_staple_price_0',
#        'mean_staple_price_1', 'mean_staple_price_2', 'mean_staple_price_3',
#        'displaced_disaster_idmc', 'flood_confirmed_idmc',
#        'displaced_flood_idmc', 'flash_idmc', 'displaced_flash_idmc',
#        'affected_flood_emdat', 'flash_confirmed_emdat',
#        'displaced_flash_emdat', 'geometry'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                          count          mean           std          min  \
# ID_0                      75.0  1.565333e+02  6.801914e+01    38.000000
# OBJECTID_1                75.0  1.681333e+02  6.196977e+01    22.000000
# POP2000                   75.0  2.242886e+07  2.861161e+07     0.000000
# SQKM                      75.0  8.290951e+05  5.688772e+05     0.000000
# POPSQKM                   75.0  3.676553e+01  3.889206e+01     0.000000
# Year                     176.0  2.014000e+03  3.171300e+00  2009.000000
# flood_extent              80.0  1.508540e-02  1.098180e-02     0.002174
# mean_flood_duration       80.0  1.471350e+01  4.977633e+00     5.761641
# mean_ipc_0                80.0  1.194301e+00  7.066705e-01     0.000000
# mean_ipc_1                80.0  1.252748e+00  6.595605e-01     0.000228
# mean_ipc_2                32.0  1.310257e+00  6.452695e-01     0.000228
# mean_ipc_3                64.0  1.427182e+00  5.992557e-01     0.001269
# mean_staple_price_0       75.0  1.079036e+00  2.134662e-01     0.559654
# mean_staple_price_1       75.0  1.003648e+00  1.932761e-01     0.538565
# mean_staple_price_2       75.0  1.056412e+00  1.950828e-01     0.587521
# mean_staple_price_3       75.0  1.078018e+00  2.265259e-01     0.565180
# displaced_disaster_idmc  153.0  1.178834e+05  3.422613e+05     0.000000
# flood_confirmed_idmc     176.0  2.670455e-01  4.436785e-01     0.000000
# displaced_flood_idmc     153.0  8.918938e+04  2.839494e+05     0.000000
# flash_idmc                47.0  1.489362e-01  3.598746e-01     0.000000
# displaced_flash_idmc      47.0  2.752766e+02  7.913862e+02     0.000000
# affected_flood_emdat     116.0  2.305804e+05  6.977698e+05    14.000000
# flash_confirmed_emdat    117.0  1.623932e-01  3.703974e-01     0.000000
# displaced_flash_emdat    116.0  1.988146e+04  8.139414e+04     0.000000
#
#                                   25%           50%           75%  \
# ID_0                     1.180000e+02  1.530000e+02  2.180000e+02
# OBJECTID_1               1.480000e+02  1.640000e+02  2.200000e+02
# POP2000                  8.777879e+06  1.135080e+07  2.330016e+07
# SQKM                     2.737192e+05  7.886289e+05  1.168002e+06
# POPSQKM                  6.751101e+00  1.672991e+01  5.555615e+01
# Year                     2.011000e+03  2.014000e+03  2.017000e+03
# flood_extent             5.794782e-03  1.264112e-02  2.167188e-02
# mean_flood_duration      1.074571e+01  1.476798e+01  1.699702e+01
# mean_ipc_0               9.883658e-01  1.032748e+00  1.691956e+00
# mean_ipc_1               9.992166e-01  1.173778e+00  1.616259e+00
# mean_ipc_2               9.885097e-01  1.240584e+00  1.671131e+00
# mean_ipc_3               1.039796e+00  1.296295e+00  1.744833e+00
# mean_staple_price_0      9.559563e-01  1.040397e+00  1.231730e+00
# mean_staple_price_1      9.106668e-01  1.011758e+00  1.128498e+00
# mean_staple_price_2      9.417576e-01  1.024934e+00  1.185795e+00
# mean_staple_price_3      9.513255e-01  1.038324e+00  1.201028e+00
# displaced_disaster_idmc  5.800000e+03  2.800000e+04  1.160000e+05
# flood_confirmed_idmc     0.000000e+00  0.000000e+00  1.000000e+00
# displaced_flood_idmc     4.760000e+03  2.040000e+04  8.500000e+04
# flash_idmc               0.000000e+00  0.000000e+00  0.000000e+00
# displaced_flash_idmc     0.000000e+00  0.000000e+00  0.000000e+00
# affected_flood_emdat     1.453750e+04  7.802500e+04  2.000010e+05
# flash_confirmed_emdat    0.000000e+00  0.000000e+00  0.000000e+00
# displaced_flash_emdat    0.000000e+00  0.000000e+00  0.000000e+00
#
#                                   max
# ID_0                     2.560000e+02
# OBJECTID_1               2.530000e+02
# POP2000                  1.138618e+08
# SQKM                     2.337027e+06
# POPSQKM                  1.248431e+02
# Year                     2.019000e+03
# flood_extent             4.906519e-02
# mean_flood_duration      3.118969e+01
# mean_ipc_0               2.978762e+00
# mean_ipc_1               3.191109e+00
# mean_ipc_2               3.151592e+00
# mean_ipc_3               3.065052e+00
# mean_staple_price_0      1.657950e+00
# mean_staple_price_1      1.488268e+00
# mean_staple_price_2      1.562413e+00
# mean_staple_price_3      1.642359e+00
# displaced_disaster_idmc  3.900000e+06
# flood_confirmed_idmc     1.000000e+00
# displaced_flood_idmc     3.315000e+06
# flash_idmc               1.000000e+00
# displaced_flash_idmc     3.750000e+03
# affected_flood_emdat     7.000867e+06
# flash_confirmed_emdat    1.000000e+00
# displaced_flash_emdat    5.000000e+05

# %% [markdown]
# # Plots

# %% [markdown]
# ### Look at Mean IPC immediately after rainy season

# %%
fig, ax = plt.subplots(2,2)
sns.histplot(ax = ax[0][0], data = df.mean_ipc_0)
sns.histplot(ax = ax[0][1], data = df.mean_ipc_1)
sns.histplot(ax = ax[1][0], data = df.mean_ipc_2)
sns.histplot(ax = ax[1][1], data = df.mean_ipc_3)

plt.show()

# %%
fig, ax = plt.subplots(nrows = 3, ncols = 2, figsize = (18, 18))

sns.scatterplot(ax = ax[0][0], x = "flood_extent", y = "mean_ipc_0", hue = 'Name', data = df, 
                legend = False).set(xlabel = None)
sns.scatterplot(ax = ax[0][1], x = "mean_flood_duration", y = "mean_ipc_0", hue = 'Name', data = df, 
                legend = False).set(xlabel = None, ylabel = None)
sns.scatterplot(ax = ax[1][0], x = "flood_extent", y = "displaced_flood_idmc", 
            hue = 'Name', data = df, legend = False).set(ylabel = "Displacement incidents (IDMC)", xlabel = None)
sns.scatterplot(ax = ax[1][1], x = "mean_flood_duration", y = "displaced_flood_idmc",
            hue = 'Name', data = df, legend = False).set(ylabel = None, xlabel = None)
sns.scatterplot(ax = ax[2][0], x = "flood_extent", y = "mean_staple_price_0", 
            hue = 'Name', data = df, legend = False).set(xlabel = 'Flood extent (% national area)', ylabel = "Mean staple prices at time 0 (USD normalized, 2015)")
sns.scatterplot(ax = ax[2][1], x = "mean_flood_duration", y = "mean_staple_price_0",
            hue = 'Name', data = df).set(xlabel = 'Mean flood duration (days of year)', ylabel = None)

handles, labels = ax[2][1].get_legend_handles_labels()
fig.legend(handles, labels, loc='center right')
ax[2][1].legend_.remove()


plt.show()

# %% [markdown]
# # Mixed effects models: flood effects on IPC ratings
#
# Below, I fit mixed effects models for each time step using the two flood covariates--flood extent and and mean flood duration--and random slopes/intercepts. This yields convergence warnings, likely because the number of parameters we're using exceed the number of data points available per group.

# %%
flood_model_0 = smf.mixedlm('mean_ipc_0 ~ flood_extent + mean_flood_duration',
                         data = df[(df.mean_ipc_0.notnull()) & (df.mean_ipc_0 != 0)], groups = 'Name',
                           re_formula = "~ flood_extent + mean_flood_duration").fit()

flood_model_1 = smf.mixedlm('mean_ipc_1 ~ flood_extent + mean_flood_duration + mean_ipc_0',
                         data = df[(df.mean_ipc_0.notnull()) & (df.mean_ipc_0 != 0) &
                                  (df.mean_ipc_1.notnull()) & (df.mean_ipc_1 != 0)], groups = 'Name',
                           re_formula = "~ flood_extent + mean_flood_duration").fit()

flood_model_2 = smf.mixedlm('mean_ipc_2 ~ flood_extent + mean_flood_duration + mean_ipc_1',
                         data = df[(df.mean_ipc_1.notnull()) & (df.mean_ipc_1 != 0) &
                                  (df.mean_ipc_2.notnull()) & (df.mean_ipc_2 != 0)], groups = 'Name',
                           re_formula = "~ flood_extent + mean_flood_duration").fit()

flood_model_3 = smf.mixedlm('mean_ipc_3 ~ flood_extent + mean_flood_duration + mean_ipc_2',
                         data = df[(df.mean_ipc_2.notnull()) & (df.mean_ipc_2 != 0) &
                                  (df.mean_ipc_3.notnull()) & (df.mean_ipc_3 != 0)], groups = 'Name',
                           re_formula = "~ flood_extent + mean_flood_duration").fit()
# Out:
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2202: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2202: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2202: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2202: ConvergenceWarning: Retrying MixedLM optimization with cg
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 3.261234
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2202: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)

# %%
print(flood_model_0.summary())
print(flood_model_1.summary())
print(flood_model_2.summary())
print(flood_model_3.summary())
# Out:
#                      Mixed Linear Model Regression Results
# ================================================================================
# Model:                    MixedLM         Dependent Variable:         mean_ipc_0
# No. Observations:         74              Method:                     REML
# No. Groups:               16              Scale:                      0.2124
# Min. group size:          4               Log-Likelihood:             -53.8493
# Max. group size:          5               Converged:                  Yes
# Mean group size:          4.6
# --------------------------------------------------------------------------------
#                                        Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# --------------------------------------------------------------------------------
# Intercept                               2.038
# flood_extent                            2.450    3.492 0.702 0.483 -4.393  9.294
# mean_flood_duration                    -0.058
# Name Var                                0.305    0.504
# Name x flood_extent Cov                 0.001    8.898
# flood_extent Var                        0.213
# Name x mean_flood_duration Cov         -0.014
# flood_extent x mean_flood_duration Cov -0.000
# mean_flood_duration Var                 0.001
# ================================================================================
#
#                       Mixed Linear Model Regression Results
# ==================================================================================
# Model:                      MixedLM         Dependent Variable:         mean_ipc_1
# No. Observations:           74              Method:                     REML
# No. Groups:                 16              Scale:                      0.2858
# Min. group size:            4               Log-Likelihood:             -62.7378
# Max. group size:            5               Converged:                  Yes
# Mean group size:            4.6
# ----------------------------------------------------------------------------------
#                                        Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# ----------------------------------------------------------------------------------
# Intercept                               1.315    0.416  3.164 0.002   0.501  2.130
# flood_extent                           -6.452    6.422 -1.005 0.315 -19.039  6.134
# mean_flood_duration                    -0.032    0.022 -1.465 0.143  -0.075  0.011
# mean_ipc_0                              0.383    0.135  2.826 0.005   0.117  0.648
# Name Var                                0.283
# Name x flood_extent Cov                -0.000
# flood_extent Var                        0.286  411.121
# Name x mean_flood_duration Cov         -0.019
# flood_extent x mean_flood_duration Cov -0.000
# mean_flood_duration Var                 0.001
# ==================================================================================
#
#                       Mixed Linear Model Regression Results
# ==================================================================================
# Model:                      MixedLM         Dependent Variable:         mean_ipc_2
# No. Observations:           32              Method:                     REML
# No. Groups:                 16              Scale:                      0.1935
# Min. group size:            2               Log-Likelihood:             -22.6888
# Max. group size:            2               Converged:                  No
# Mean group size:            2.0
# ----------------------------------------------------------------------------------
#                                        Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# ----------------------------------------------------------------------------------
# Intercept                               2.068    0.927  2.232 0.026   0.252  3.884
# flood_extent                           -4.651   24.161 -0.192 0.847 -52.006 42.704
# mean_flood_duration                    -0.070    0.029 -2.434 0.015  -0.126 -0.014
# mean_ipc_1                              0.320    0.365  0.876 0.381  -0.396  1.036
# Name Var                                0.256    1.648
# Name x flood_extent Cov                 0.000  116.818
# flood_extent Var                        0.193 2788.889
# Name x mean_flood_duration Cov         -0.014    0.104
# flood_extent x mean_flood_duration Cov  0.001    3.261
# mean_flood_duration Var                 0.001    0.007
# ==================================================================================
#
#                       Mixed Linear Model Regression Results
# =================================================================================
# Model:                     MixedLM         Dependent Variable:         mean_ipc_3
# No. Observations:          16              Method:                     REML
# No. Groups:                16              Scale:                      0.0074
# Min. group size:           1               Log-Likelihood:             6.6657
# Max. group size:           1               Converged:                  Yes
# Mean group size:           1.0
# ---------------------------------------------------------------------------------
#                                        Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ---------------------------------------------------------------------------------
# Intercept                              -0.044    0.261 -0.169 0.866 -0.556  0.468
# flood_extent                           -1.264
# mean_flood_duration                    -0.000    0.006 -0.045 0.964 -0.011  0.011
# mean_ipc_2                              1.075
# Name Var                                0.041    0.733
# Name x flood_extent Cov                 0.000   19.672
# flood_extent Var                        0.007
# Name x mean_flood_duration Cov         -0.002    0.021
# flood_extent x mean_flood_duration Cov -0.000
# mean_flood_duration Var                 0.000
# =================================================================================
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2711: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2711: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))

# %%
flood_model_0.pvalues
# Out:
# Intercept                                      NaN
# flood_extent                              0.482797
# mean_flood_duration                            NaN
# Name Var                                  0.189145
# Name x flood_extent Cov                   0.999775
# flood_extent Var                               NaN
# Name x mean_flood_duration Cov                 NaN
# flood_extent x mean_flood_duration Cov         NaN
# mean_flood_duration Var                        NaN
# dtype: float64

# %% [markdown]
# We see that flood extent is never significant, so below, I fit a few models just using mean flood duration to see how the results vary.

# %%
flood_model_0_2 = smf.mixedlm('mean_ipc_0 ~ mean_flood_duration',
                         data = df[df.mean_ipc_0 != 0], groups = 'Name',
                           re_formula = "~ mean_flood_duration", missing = 'drop').fit()
flood_model_0_2.summary()
# Out:
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2202: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                   MixedLM      Dependent Variable:      mean_ipc_0
# No. Observations:        74           Method:                  REML
# No. Groups:              16           Scale:                   0.2123
# Min. group size:         4            Log-Likelihood:          -57.0929
# Max. group size:         5            Converged:               Yes
# Mean group size:         4.6
# -------------------------------------------------------------------------
#                                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------
# Intercept                       2.022    0.176 11.505 0.000  1.677  2.366
# mean_flood_duration            -0.055    0.009 -6.184 0.000 -0.072 -0.037
# Name Var                        0.337    0.468
# Name x mean_flood_duration Cov -0.016    0.027
# mean_flood_duration Var         0.001    0.001
# =========================================================================
#
# """

# %%
flood_model_1_2 = smf.mixedlm('mean_ipc_1 ~ mean_flood_duration + mean_ipc_0',
                         data = df[(df.mean_ipc_0 != 0) &
                                  (df.mean_ipc_1 != 0)], groups = 'Name', missing = 'drop',
                           re_formula = "~ mean_flood_duration").fit()
flood_model_1_2.summary()
# Out:
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2202: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                   MixedLM      Dependent Variable:      mean_ipc_1
# No. Observations:        74           Method:                  REML
# No. Groups:              16           Scale:                   0.2549
# Min. group size:         4            Log-Likelihood:          -61.8068
# Max. group size:         5            Converged:               Yes
# Mean group size:         4.6
# -------------------------------------------------------------------------
#                                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------
# Intercept                       1.094    0.351  3.120 0.002  0.407  1.782
# mean_flood_duration            -0.017    0.017 -1.031 0.303 -0.049  0.015
# mean_ipc_0                      0.295    0.121  2.442 0.015  0.058  0.532
# Name Var                        0.236    1.586
# Name x mean_flood_duration Cov -0.013    0.108
# mean_flood_duration Var         0.001    0.006
# =========================================================================
#
# """

# %%
flood_model_2_2 = smf.mixedlm('mean_ipc_2 ~ mean_flood_duration + mean_ipc_1',
                         data = df[(df.mean_ipc_1.notnull()) & (df.mean_ipc_1 != 0) &
                                  (df.mean_ipc_2.notnull()) & (df.mean_ipc_2 != 0)], groups = 'Name',
                           re_formula = "~ mean_flood_duration").fit()

# %%
flood_model_3_2 = smf.mixedlm('mean_ipc_3 ~ mean_flood_duration + mean_ipc_2',
                         data = df[(df.mean_ipc_2.notnull()) & (df.mean_ipc_2 != 0) &
                                  (df.mean_ipc_3.notnull()) & (df.mean_ipc_3 != 0)], groups = 'Name',
                           re_formula = "~ mean_flood_duration").fit()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-f9aad5451017> in <module>
#       1 flood_model_0_2 = smf.mixedlm('mean_ipc_0 ~ mean_flood_duration',
#       2                          data = df[(df.mean_ipc_0.notnull()) & (df.mean_ipc_0 != 0)], groups = 'Name',
# ----> 3                            re_formula = "~ mean_flood_duration").fit().summary()
#       4
#       5 flood_model_1_2 = smf.mixedlm('mean_ipc_1 ~ mean_flood_duration + mean_ipc_0',
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py in from_formula(cls, formula, data, re_formula, vc_formula, subset, use_sparse, missing, *args, **kwargs)
#    1045         kwargs["groups"] = groups
#    1046         mod = super(MixedLM, cls).from_formula(
# -> 1047             formula, data, *args, **kwargs)
#    1048
#    1049         # expand re names to account for pairs of RE
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in from_formula(cls, formula, data, subset, drop_cols, *args, **kwargs)
#     193                        'formula': formula,  # attach formula for unpckling
#     194                        'design_info': design_info})
# --> 195         mod = cls(endog, exog, *args, **kwargs)
#     196         mod.formula = formula
#     197
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py in __init__(self, endog, exog, groups, exog_re, exog_vc, use_sqrt, missing, **kwargs)
#     741         super(MixedLM, self).__init__(endog, exog, groups=groups,
#     742                                       exog_re=exog_re, missing=missing,
# --> 743                                       **kwargs)
#     744
#     745         self._init_keys.extend(["use_sqrt", "exog_vc"])
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#     235
#     236     def __init__(self, endog, exog=None, **kwargs):
# --> 237         super(LikelihoodModel, self).__init__(endog, exog, **kwargs)
#     238         self.initialize()
#     239
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in __init__(self, endog, exog, **kwargs)
#      76         hasconst = kwargs.pop('hasconst', None)
#      77         self.data = self._handle_data(endog, exog, missing, hasconst,
# ---> 78                                       **kwargs)
#      79         self.k_constant = self.data.k_constant
#      80         self.exog = self.data.exog
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py in _handle_data(self, endog, exog, missing, hasconst, **kwargs)
#      99
#     100     def _handle_data(self, endog, exog, missing, hasconst, **kwargs):
# --> 101         data = handle_data(endog, exog, missing, hasconst, **kwargs)
#     102         # kwargs arrays could have changed, easier to just attach here
#     103         for key in kwargs:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/data.py in handle_data(endog, exog, missing, hasconst, **kwargs)
#     671     klass = handle_data_class_factory(endog, exog)
#     672     return klass(endog, exog=exog, missing=missing, hasconst=hasconst,
# --> 673                  **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/data.py in __init__(self, endog, exog, missing, hasconst, **kwargs)
#      70         if missing != 'none':
#      71             arrays, nan_idx = self.handle_missing(endog, exog, missing,
# ---> 72                                                   **kwargs)
#      73             self.missing_row_idx = nan_idx
#      74             self.__dict__.update(arrays)  # attach all the data arrays
#
# ~/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/data.py in handle_missing(cls, endog, exog, missing, **kwargs)
#     254                 combined_2d_nans = _nan_rows(combined_2d)
#     255                 if combined_2d_nans.shape[0] != nan_mask.shape[0]:
# --> 256                     raise ValueError("Shape mismatch between endog/exog "
#     257                                      "and extra 2d arrays given to model.")
#     258                 if updated_row_mask is not None:
#
# ValueError: Shape mismatch between endog/exog and extra 2d arrays given to model.

# %%
print(flood_model_0_2.summary())
print(flood_model_1_2.summary())
print(flood_model_2_2.summary())
print(flood_model_3_2.summary())
# Out:
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                   MixedLM      Dependent Variable:      mean_ipc_0
# No. Observations:        74           Method:                  REML
# No. Groups:              16           Scale:                   0.2120
# Min. group size:         4            Log-Likelihood:          -56.6852
# Max. group size:         5            Converged:               Yes
# Mean group size:         4.6
# -------------------------------------------------------------------------
#                                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------
# Intercept                       2.063    0.201 10.291 0.000  1.670  2.456
# mean_flood_duration            -0.057    0.015 -3.853 0.000 -0.086 -0.028
# Name Var                        0.289    0.456
# Name x mean_flood_duration Cov -0.013    0.031
# mean_flood_duration Var         0.001    0.002
# =========================================================================
#
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                   MixedLM      Dependent Variable:      mean_ipc_1
# No. Observations:        74           Method:                  REML
# No. Groups:              16           Scale:                   0.2834
# Min. group size:         4            Log-Likelihood:          -65.9913
# Max. group size:         5            Converged:               Yes
# Mean group size:         4.6
# -------------------------------------------------------------------------
#                                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------
# Intercept                       1.279    0.647  1.977 0.048  0.011  2.547
# mean_flood_duration            -0.036    0.043 -0.842 0.400 -0.121  0.048
# mean_ipc_0                      0.377    0.126  2.995 0.003  0.130  0.624
# Name Var                        0.281
# Name x mean_flood_duration Cov -0.021
# mean_flood_duration Var         0.002    0.002
# =========================================================================
#
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                   MixedLM      Dependent Variable:      mean_ipc_2
# No. Observations:        32           Method:                  REML
# No. Groups:              16           Scale:                   0.1989
# Min. group size:         2            Log-Likelihood:          -25.9113
# Max. group size:         2            Converged:               Yes
# Mean group size:         2.0
# -------------------------------------------------------------------------
#                                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------
# Intercept                       1.951    0.520  3.752 0.000  0.932  2.970
# mean_flood_duration            -0.067    0.028 -2.408 0.016 -0.122 -0.013
# mean_ipc_1                      0.333    0.172  1.938 0.053 -0.004  0.670
# Name Var                        0.251    0.679
# Name x mean_flood_duration Cov -0.014    0.047
# mean_flood_duration Var         0.001    0.003
# =========================================================================
#
#                   Mixed Linear Model Regression Results
# =========================================================================
# Model:                   MixedLM      Dependent Variable:      mean_ipc_3
# No. Observations:        16           Method:                  REML
# No. Groups:              16           Scale:                   0.0053
# Min. group size:         1            Log-Likelihood:          3.9034
# Max. group size:         1            Converged:               No
# Mean group size:         1.0
# -------------------------------------------------------------------------
#                                Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------------
# Intercept                      -0.086    0.190 -0.450 0.653 -0.458  0.287
# mean_flood_duration             0.001    0.006  0.138 0.890 -0.011  0.013
# mean_ipc_2                      1.080    0.094 11.509 0.000  0.896  1.263
# Name Var                        0.029
# Name x mean_flood_duration Cov -0.001
# mean_flood_duration Var         0.000
# =========================================================================

# %% [markdown]
# ## Restrict geography
#
# One shortcoming of our flood data is that it represents an annual aggregation of flood events for each country on a January – December calendar. We assume that the majority of flood events happen during the summer monsoon season (June – September), but this assumption doesn't hold for the eastern and southeastern countries with bimodal rainy seasons or rainy seasons which occur over December – February. Below, I filter the original dataset to West African countries whose rainy seasons fit our assumptions and run the above models.

# %%
df_wa = df[df.Name.isin(['Mauritania', 'Mali', 'Burkina Faso', 'Niger', 'Nigeria', 'Chad', 'Sudan', 'South Sudan'])]

# %%
flood_model_0_3 = smf.mixedlm('mean_ipc_0 ~ flood_extent + mean_flood_duration + mean_staple_price_0',
                         data = df_wa[(df_wa.mean_ipc_0.notnull()) & (df_wa.mean_ipc_0 != 0)], groups = 'Name',
                           re_formula = "~ flood_extent + mean_flood_duration").fit()

flood_model_1_3 = smf.mixedlm('mean_ipc_1 ~ flood_extent + mean_flood_duration + mean_ipc_0 + mean_staple_price_1',
                         data = df_wa[(df_wa.mean_ipc_0.notnull()) & (df_wa.mean_ipc_0 != 0) &
                                  (df_wa.mean_ipc_1.notnull()) & (df_wa.mean_ipc_1 != 0)], groups = 'Name',
                           re_formula = "~ flood_extent + mean_flood_duration").fit()

flood_model_2_3 = smf.mixedlm('mean_ipc_2 ~ flood_extent + mean_flood_duration + mean_ipc_1 + mean_staple_price_2',
                         data = df_wa[(df_wa.mean_ipc_1.notnull()) & (df_wa.mean_ipc_1 != 0) &
                                  (df_wa.mean_ipc_2.notnull()) & (df_wa.mean_ipc_2 != 0)], groups = 'Name',
                           re_formula = "~ flood_extent + mean_flood_duration").fit()

flood_model_3_3 = smf.mixedlm('mean_ipc_3 ~ flood_extent + mean_flood_duration + mean_ipc_2 + mean_staple_price_3',
                         data = df_wa[(df_wa.mean_ipc_2.notnull()) & (df_wa.mean_ipc_2 != 0) &
                                  (df_wa.mean_ipc_3.notnull()) & (df_wa.mean_ipc_3 != 0)], groups = 'Name',
                           re_formula = "~ flood_extent + mean_flood_duration").fit()
# Out:
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2202: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2202: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2202: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2202: ConvergenceWarning: Retrying MixedLM optimization with cg
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 2.384526
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2202: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2202: ConvergenceWarning: Retrying MixedLM optimization with cg
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 2.000970
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)

# %%
print(flood_model_0_3.summary())
print(flood_model_1_3.summary())
print(flood_model_2_3.summary())
print(flood_model_3_3.summary())
# Out:
#                       Mixed Linear Model Regression Results
# ==================================================================================
# Model:                      MixedLM         Dependent Variable:         mean_ipc_0
# No. Observations:           37              Method:                     REML
# No. Groups:                 8               Scale:                      0.1759
# Min. group size:            4               Log-Likelihood:             -21.6715
# Max. group size:            5               Converged:                  Yes
# Mean group size:            4.6
# ----------------------------------------------------------------------------------
#                                        Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# ----------------------------------------------------------------------------------
# Intercept                               1.891    0.757  2.498 0.012   0.407  3.374
# flood_extent                           12.574   37.372  0.336 0.737 -60.673 85.821
# mean_flood_duration                    -0.033    0.046 -0.715 0.475  -0.124  0.058
# mean_staple_price_0                    -0.354    0.442 -0.802 0.423  -1.220  0.512
# Name Var                                0.296    1.355
# Name x flood_extent Cov                 0.001   56.934
# flood_extent Var                        0.176 1485.310
# Name x mean_flood_duration Cov         -0.014    0.067
# flood_extent x mean_flood_duration Cov -0.000    3.786
# mean_flood_duration Var                 0.001    0.003
# ==================================================================================
#
#                       Mixed Linear Model Regression Results
# ==================================================================================
# Model:                      MixedLM         Dependent Variable:         mean_ipc_1
# No. Observations:           37              Method:                     REML
# No. Groups:                 8               Scale:                      0.3030
# Min. group size:            4               Log-Likelihood:             -30.0711
# Max. group size:            5               Converged:                  Yes
# Mean group size:            4.6
# ----------------------------------------------------------------------------------
#                                        Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# ----------------------------------------------------------------------------------
# Intercept                               1.836    0.838  2.192 0.028   0.194  3.477
# flood_extent                            4.175   31.099  0.134 0.893 -56.777 65.128
# mean_flood_duration                    -0.009    0.036 -0.247 0.805  -0.080  0.062
# mean_ipc_0                              0.223    0.304  0.732 0.464  -0.373  0.819
# mean_staple_price_1                    -0.769    0.568 -1.354 0.176  -1.882  0.344
# Name Var                                0.272
# Name x flood_extent Cov                -0.000   44.345
# flood_extent Var                        0.303  816.691
# Name x mean_flood_duration Cov         -0.014
# flood_extent x mean_flood_duration Cov  0.000    2.432
# mean_flood_duration Var                 0.001
# ==================================================================================
#
#                        Mixed Linear Model Regression Results
# ====================================================================================
# Model:                      MixedLM          Dependent Variable:          mean_ipc_2
# No. Observations:           16               Method:                      REML
# No. Groups:                 8                Scale:                       0.1794
# Min. group size:            2                Log-Likelihood:              -9.3928
# Max. group size:            2                Converged:                   No
# Mean group size:            2.0
# ------------------------------------------------------------------------------------
#                                        Coef.  Std.Err.   z    P>|z|  [0.025   0.975]
# ------------------------------------------------------------------------------------
# Intercept                               3.635    0.955  3.804 0.000    1.762   5.507
# flood_extent                           14.379   84.688  0.170 0.865 -151.606 180.364
# mean_flood_duration                    -0.094    0.061 -1.549 0.121   -0.214   0.025
# mean_ipc_1                              0.308    0.338  0.913 0.361   -0.354   0.970
# mean_staple_price_2                    -1.164    1.254 -0.928 0.353   -3.623   1.294
# Name Var                                0.215    4.015
# Name x flood_extent Cov                 0.000  131.484
# flood_extent Var                        0.179 7197.217
# Name x mean_flood_duration Cov         -0.020    0.160
# flood_extent x mean_flood_duration Cov -0.000    5.746
# mean_flood_duration Var                 0.002    0.007
# ====================================================================================
#
#                      Mixed Linear Model Regression Results
# ================================================================================
# Model:                    MixedLM         Dependent Variable:         mean_ipc_3
# No. Observations:         8               Method:                     REML
# No. Groups:               8               Scale:                      0.0004
# Min. group size:          1               Log-Likelihood:             5.4467
# Max. group size:          1               Converged:                  No
# Mean group size:          1.0
# --------------------------------------------------------------------------------
#                                        Coef.  Std.Err.   z   P>|z| [0.025 0.975]
# --------------------------------------------------------------------------------
# Intercept                              -1.140
# flood_extent                            1.501
# mean_flood_duration                     0.008
# mean_ipc_2                              1.347    0.571 2.358 0.018  0.227  2.466
# mean_staple_price_3                     0.485
# Name Var                                0.011    9.564
# Name x flood_extent Cov                 0.000  892.713
# flood_extent Var                        0.000
# Name x mean_flood_duration Cov         -0.001
# flood_extent x mean_flood_duration Cov -0.000   56.013
# mean_flood_duration Var                 0.000
# ================================================================================
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2711: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))

# %% [markdown]
# The above suggests that neither mean flood duration nor flood extent are significant predictors of mean IPC rating for any of the selected West African countries. While we see some significance in the final time step, there is not really enough data in that model for us to be super confident in that result. What's additionally interesting is that IPC ratings from the previous season seem to not be strong predictors of mean IPC in the next season here, where they typically were significant when considering all of the countries together.

# %% [markdown]
# # Mixed effects models: flood effects on displacement

# %%
disp_model_0 = smf.mixedlm('displaced_flood_idmc ~ flood_extent + mean_flood_duration + mean_staple_price_0 + mean_ipc_0',
                         data = df, groups = 'Name', missing = 'drop',
                           re_formula = "~ flood_extent + mean_flood_duration").fit()
# Out:
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/base/model.py:568: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   ConvergenceWarning)
# /Users/connor/opt/anaconda3/lib/python3.7/site-packages/statsmodels/regression/mixed_linear_model.py:2202: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   ConvergenceWarning)

# %%
disp_model_0.summary()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                                 Mixed Linear Model Regression Results
# ======================================================================================================
# Model:                        MixedLM             Dependent Variable:             displaced_flood_idmc
# No. Observations:             68                  Method:                         REML
# No. Groups:                   15                  Scale:                          9973567125.8334
# Min. group size:              2                   Log-Likelihood:                 -822.8147
# Max. group size:              5                   Converged:                      Yes
# Mean group size:              4.5
# ------------------------------------------------------------------------------------------------------
#                                            Coef.        Std.Err.    z    P>|z|    [0.025      0.975]
# ------------------------------------------------------------------------------------------------------
# Intercept                                    7228.412  114884.192  0.063 0.950 -217940.467  232397.290
# flood_extent                              2371824.596 1519671.092  1.561 0.119 -606676.012 5350325.205
# mean_flood_duration                          -643.520    6588.611 -0.098 0.922  -13556.961   12269.921
# mean_staple_price_0                         42686.574   65256.501  0.654 0.513  -85213.818  170586.965
# mean_ipc_0                                 -11539.311   17679.472 -0.653 0.514  -46190.438   23111.817
# Name Var                               9419742584.093  177573.756
# Name x flood_extent Cov                  -3078320.082 7781451.814
# flood_extent Var                       9973873838.135
# Name x mean_flood_duration Cov         -543748761.357
# flood_extent x mean_flood_duration Cov     109152.763  562954.743
# mean_flood_duration Var                  32990226.195
# ======================================================================================================
#
# """

# %% [markdown]
# # SEM

# %% [markdown]
# This section needs to be developed more, but essentially, I'm hoping to use the SEM approach to explore how the effects of flooding on food insecurity and displacement might be mediated by other factors, such as crop production/prices, rates of disease incidence, infrastructure effects, etc.
#
# Much of the data is forthcoming, but this initial models explore mean staple prices as a mediating construct.

# %%
mod_time0 = '''
            
            mean_staple_price_0 ~ flood_extent + mean_flood_duration
            displaced_flood_idmc ~ flood_extent + mean_flood_duration
            mean_ipc_0 ~ mean_staple_price_0 + displaced_flood_idmc + flood_extent + mean_flood_duration
'''

mod0 = semopy.Model(mod_time0)

mod_time1 = '''
            
            mean_staple_price_1 ~ flood_extent + mean_flood_duration + mean_staple_price_0
            mean_ipc_1 ~ mean_staple_price_1 + mean_ipc_0 + flood_extent + mean_flood_duration
'''

mod1 = semopy.Model(mod_time1)

mod_time2 = '''
            
            mean_staple_price_2 ~ flood_extent + mean_flood_duration + mean_staple_price_1
            mean_ipc_2 ~ mean_staple_price_2 + mean_ipc_1 + flood_extent + mean_flood_duration
'''

mod2 = semopy.Model(mod_time2)

mod_time3 = '''
            
            mean_staple_price_3 ~ flood_extent + mean_flood_duration + mean_staple_price_2
            mean_ipc_3 ~ mean_staple_price_2 + mean_ipc_2 + flood_extent + mean_flood_duration
'''

mod3 = semopy.Model(mod_time3)

# %%
mod0.fit(data = df, groups = ['Name'])
mod1.fit(data = df, groups = ['Name'])
mod2.fit(data = df, groups = ['Name'])
mod3.fit(data = df, groups = ['Name'])
# Out:
# SolverResult(fun=0.019440563904472796, success=True, n_it=44, x=array([-1.08273621e+00,  4.27741716e-03,  8.91975595e-01,  1.57360637e-01,
#         7.41506533e-01, -1.84068528e+01,  3.77606612e-02,  3.58441749e-02,
#         9.33318654e-03]), message='Optimization terminated successfully', name_method='SLSQP', name_obj='MLW')

# %%
mod0.inspect()
# Out:
#                     lval  op                  rval      Estimate  \
# 0    mean_staple_price_0   ~          flood_extent -6.109052e+00
# 1    mean_staple_price_0   ~   mean_flood_duration  1.605964e-02
# 2   displaced_flood_idmc   ~          flood_extent -2.216393e-05
# 3   displaced_flood_idmc   ~   mean_flood_duration  1.618982e-02
# 4             mean_ipc_0   ~   mean_staple_price_0  4.588678e-01
# 5             mean_ipc_0   ~  displaced_flood_idmc -8.475322e-08
# 6             mean_ipc_0   ~          flood_extent  1.656288e+01
# 7             mean_ipc_0   ~   mean_flood_duration -5.115075e-02
# 8    mean_staple_price_0  ~~   mean_staple_price_0  2.191432e-02
# 9   displaced_flood_idmc  ~~  displaced_flood_idmc  3.398073e+10
# 10            mean_ipc_0  ~~            mean_ipc_0  2.227602e-01
#
#         Std. Err       z-value   p-value
# 0   3.262257e+00 -1.872646e+00  0.061117
# 1   5.260093e-03  3.053110e+00  0.002265
# 2   4.062286e+06 -5.456024e-12  1.000000
# 3   6.550067e+03  2.471703e-06  0.999998
# 4   2.403248e-01  1.909365e+00  0.056215
# 5   1.929951e-07 -4.391448e-01  0.660557
# 6   1.050406e+01  1.576807e+00  0.114840
# 7   1.720897e-02 -2.972331e+00  0.002955
# 8   2.336074e-03  9.380832e+00  0.000000
# 9   3.622358e+09  9.380832e+00  0.000000
# 10  2.374632e-02  9.380832e+00  0.000000

# %%
mod1.inspect()
# Out:
#                   lval  op                 rval   Estimate   Std. Err  \
# 0  mean_staple_price_1   ~         flood_extent   4.265949   2.388586
# 1  mean_staple_price_1   ~  mean_flood_duration  -0.004421   0.003913
# 2  mean_staple_price_1   ~  mean_staple_price_0   0.748155   0.054648
# 3           mean_ipc_1   ~  mean_staple_price_1  -0.228589   0.240390
# 4           mean_ipc_1   ~           mean_ipc_0   0.189215   0.077655
# 5           mean_ipc_1   ~         flood_extent  10.618559  10.836042
# 6           mean_ipc_1   ~  mean_flood_duration  -0.027131   0.017849
# 7  mean_staple_price_1  ~~  mean_staple_price_1   0.011519   0.001228
# 8           mean_ipc_1  ~~           mean_ipc_1   0.239318   0.025511
#
#      z-value   p-value
# 0   1.785973  0.074104
# 1  -1.129823  0.258551
# 2  13.690529  0.000000
# 3  -0.950910  0.341650
# 4   2.436603  0.014826
# 5   0.979930  0.327121
# 6  -1.520033  0.128503
# 7   9.380832  0.000000
# 8   9.380832  0.000000

# %%
mod2.inspect()
# Out:
#                   lval  op                 rval  Estimate  Std. Err   z-value  \
# 0  mean_staple_price_2   ~         flood_extent -2.521749  3.262868 -0.772863
# 1  mean_staple_price_2   ~  mean_flood_duration  0.013775  0.005290  2.604250
# 2  mean_staple_price_2   ~  mean_staple_price_1  0.342781  0.072365  4.736823
# 3           mean_ipc_2   ~  mean_staple_price_2 -0.642855  0.125758 -5.111859
# 4           mean_ipc_2   ~           mean_ipc_1  0.228071  0.039732  5.740256
# 5           mean_ipc_2   ~         flood_extent -4.632704  5.812780 -0.796986
# 6           mean_ipc_2   ~  mean_flood_duration -0.071911  0.009654 -7.449005
# 7  mean_staple_price_2  ~~  mean_staple_price_2  0.021922  0.002337  9.380832
# 8           mean_ipc_2  ~~           mean_ipc_2  0.068784  0.007332  9.380832
#
#         p-value
# 0  4.396035e-01
# 1  9.207562e-03
# 2  2.170942e-06
# 3  3.190047e-07
# 4  9.453379e-09
# 5  4.254592e-01
# 6  9.414691e-14
# 7  0.000000e+00
# 8  0.000000e+00

# %%
mod3.inspect()
# Out:
#                   lval  op                 rval   Estimate  Std. Err  \
# 0  mean_staple_price_3   ~         flood_extent  -1.082736  2.132443
# 1  mean_staple_price_3   ~  mean_flood_duration   0.004277  0.003516
# 2  mean_staple_price_3   ~  mean_staple_price_2   0.891976  0.046320
# 3           mean_ipc_3   ~  mean_staple_price_2   0.157361  0.096235
# 4           mean_ipc_3   ~           mean_ipc_2   0.741507  0.049940
# 5           mean_ipc_3   ~         flood_extent -18.406853  4.179736
# 6           mean_ipc_3   ~  mean_flood_duration   0.037761  0.007975
# 7           mean_ipc_3  ~~           mean_ipc_3   0.035844  0.003821
# 8  mean_staple_price_3  ~~  mean_staple_price_3   0.009333  0.000995
#
#      z-value   p-value
# 0  -0.507744  0.611633
# 1   1.216697  0.223720
# 2  19.256799  0.000000
# 3   1.635168  0.102014
# 4  14.848021  0.000000
# 5  -4.403831  0.000011
# 6   4.734587  0.000002
# 7   9.380832  0.000000
# 8   9.380832  0.000000

# %%
mod_time0_disp = '''
            
            mean_staple_price_0 ~ flood_extent + mean_flood_duration
            mean_ipc_0 ~ flood_extent + mean_flood_duration + mean_staple_price_0
            displaced_flood_idmc ~ mean_staple_price_0 + mean_ipc_0 + flood_extent + mean_flood_duration
'''

mod0 = semopy.Model(mod_time0)

# %% [markdown]
# # Nigeria Only

# %%
fig, ax = plt.subplots(nrows = 3, ncols = 2, figsize = (18, 18))

sns.scatterplot(ax = ax[0][0], x = "flood_extent", y = "mean_ipc_0", hue = 'Name', data = df.loc[df['Name'] == 'Nigeria'], 
                legend = False).set(xlabel = None)
sns.scatterplot(ax = ax[0][1], x = "mean_flood_duration", y = "mean_ipc_0", hue = 'Name', data = df.loc[df['Name'] == 'Nigeria'], 
                legend = False).set(xlabel = None, ylabel = None)
sns.scatterplot(ax = ax[1][0], x = "flood_extent", y = "displaced_flood_idmc", 
            hue = 'Name', data = df.loc[df['Name'] == 'Nigeria'], legend = False).set(ylabel = "Displacement incidents (IDMC)", xlabel = None)
sns.scatterplot(ax = ax[1][1], x = "mean_flood_duration", y = "displaced_flood_idmc",
            hue = 'Name', data = df.loc[df['Name'] == 'Nigeria'], legend = False).set(ylabel = None, xlabel = None)
sns.scatterplot(ax = ax[2][0], x = "flood_extent", y = "mean_staple_price_0", 
            hue = 'Name', data = df.loc[df['Name'] == 'Nigeria'], legend = False).set(xlabel = 'Flood extent (% national area)', ylabel = "Mean staple prices at time 0 (USD normalized, 2015)")
sns.scatterplot(ax = ax[2][1], x = "mean_flood_duration", y = "mean_staple_price_0",
            hue = 'Name', data = df.loc[df['Name'] == 'Nigeria']).set(xlabel = 'Mean flood duration (days of year)', ylabel = None)

handles, labels = ax[2][1].get_legend_handles_labels()
fig.legend(handles, labels, loc='center right')
ax[2][1].legend_.remove()


plt.show()
